# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker
# Define path to the folder containing your data
folder_path = 'P:/LAB/Manuel/2023/2023-09/Microscopy/20230925_FliC-morpho_DflhE/MicrobeJ_Python/'

# Load your data - adjust the filename as needed
df = pd.read_csv(folder_path + 'MicrobeJ_Results_partialcleaned.csv', sep=',')

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of       NAME  ASSOCIATION     EXPERIMENT    IMAGE  INTENSITY  \
# 0       b1            0  Experiment 12  EM15686  5551.4120
# 1       b2            0  Experiment 12  EM15686  5662.7427
# 2       b3            0  Experiment 12  EM15686  5579.5396
# 3       b4            0  Experiment 12  EM15686  5618.6480
# 4       b5            0  Experiment 12  EM15686  5578.0894
# ...    ...          ...            ...      ...        ...
# 3115  b834            0  Experiment 17  EM15710  6240.9937
# 3116  b836            0  Experiment 17  EM15710  6683.9710
# 3117  b837            0  Experiment 17  EM15710  6609.1640
# 3118  b847            0  Experiment 17  EM15710  6204.8696
# 3119  b848            0  Experiment 17  EM15710  6353.2100
#
#       INTENSITY.ch1.mean            LOCATION  MEDIAL  POSITION  \
# 0              93.638520    (x=3.89 y=92.97)       1         1
# 1              90.920930    (x=4.70 y=86.92)       1         1
# ...

# %%
print(df.groupby('IMAGE').size())
# Out:
# IMAGE
# EM15686    566
# EM15706    402
# EM15707    605
# EM15708    464
# EM15709    595
# EM15710    488
# dtype: int64

# %%
order = ['EM15686', 'EM15706','EM15707','EM15707','EM15708','EM15709','EM15710']
# Create a new figure for the violin plot
plt.figure(figsize=(10,6))

# Create the boxenplot plot
sns.boxenplot(x="IMAGE", y="SHAPE.curvature",
              color="gray",
              scale="linear", data=df, order=order)


# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('Curvature')
plt.title('Curvature')
plt.ylim([0, 1])  # adjust as needed

# Save figure
#plt.savefig('P:/LAB/Manuel/20230925_FliC-morpho_DflhE/curvature.tiff', format='tiff', dpi=300)
# Show plot
plt.show()

# %%
order = ['EM15686', 'EM15706','EM15707','EM15707','EM15708','EM15709','EM15710']
# Create a new figure for the violin plot
plt.figure(figsize=(10,6))

# Create the boxenplot plot
sns.boxenplot(x="IMAGE", y="SHAPE.area",
              color="gray",
              scale="linear", data=df, order=order)


# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('Area')
plt.title('Area')
plt.ylim([0, 10])  # adjust as needed

# Save figure
#plt.savefig('P:/LAB/Manuel/20230925_FliC-morpho_DflhE/area.tiff', format='tiff', dpi=300)
# Show plot
plt.show()

# %%
order = ['EM15686', 'EM15706','EM15707','EM15707','EM15708','EM15709','EM15710']
# Create a new figure for the violin plot
plt.figure(figsize=(10,6))

# Create the boxenplot plot
sns.boxenplot(x="IMAGE", y="SHAPE.circularity",
              color="gray",
              scale="linear", data=df, order=order)


# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('Circularity')
plt.title('Circularity')
plt.ylim([0, 1])  # adjust as needed
# Save figure
#plt.savefig('P:/LAB/Manuel/20230925_FliC-morpho_DflhE/circularity.tiff', format='tiff', dpi=300)
# Show plot
plt.show()

# %%
order = ['EM15686', 'EM15706','EM15707','EM15708','EM15709','EM15710']
# Create a new figure for the violin plot
plt.figure(figsize=(10,6))

# Create the boxenplot plot
sns.boxenplot(x="IMAGE", y="INTENSITY.ch1.mean",
              color="red",
              scale="linear", data=df, order=order)


# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('STAR RED')
plt.title('STAR RED')
plt.ylim([0, 4000])  # adjust as needed
# Save figure
#plt.savefig('P:/LAB/Manuel/20230925_FliC-morpho_DflhE/STAR RED.tiff', format='tiff', dpi=300)
# Show plot
plt.show()

# %%
order = ['EM15686', 'EM15706','EM15707','EM15707','EM15708','EM15709','EM15710']

# Reshape the dataframe for plotting
df_melted = df.melt(id_vars='IMAGE', value_vars=['SHAPE.curvature', 'SHAPE.circularity'], 
                    var_name='Parameter', value_name='Value')

# Filter data based on the order
df_melted = df_melted[df_melted['IMAGE'].isin(order)]

# Create a new figure for the violin plot
plt.figure(figsize=(12,6))

# Create the boxenplot with hue for different parameters
sns.boxenplot(x="IMAGE", y="Value", hue="Parameter", data=df_melted, order=order, palette=["#666666", "#CCCCCC"])

# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('Value')
plt.title('Curvature and Circularity')
plt.legend(title='Parameter')
plt.ylim([0, 1])  # adjust as needed

# Move the legend outside of the plot to the right
plt.legend(title='Parameter', bbox_to_anchor=(0.755, 1.165), loc='upper left')
# Save figure
#plt.savefig('P:/LAB/Manuel/20230925_FliC-morpho_DflhE/curvature-circularity2.tiff', format='tiff', dpi=300)
# Show plot
plt.show()

# %%
order = ['EM15686', 'EM15706','EM15707','EM15707','EM15708','EM15709','EM15710']
# Reshape the dataframe for plotting
df_melted = df.melt(id_vars='IMAGE', value_vars=['SHAPE.area', 'SHAPE.length'], 
                    var_name='Parameter', value_name='Value')

# Filter data based on the order
df_melted = df_melted[df_melted['IMAGE'].isin(order)]

# Create a new figure for the violin plot
plt.figure(figsize=(12,6))

# Create the boxenplot with hue for different parameters
sns.boxenplot(x="IMAGE", y="Value", hue="Parameter", data=df_melted, order=order, palette=["#666666", "#CCCCCC"])

# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('Value')
plt.title('Area and Length')
plt.legend(title='Parameter')
plt.ylim([0, 10])  # adjust as needed

# Move the legend outside of the plot to the right
plt.legend(title='Parameter', bbox_to_anchor=(0.755, 1.165), loc='upper left')
# Save figure
#plt.savefig('P:/LAB/Manuel/20230925_FliC-morpho_DflhE/area-length.tiff', format='tiff', dpi=300)
# Show plot
plt.show()

# %%
order = ['EM15686', 'EM15706','EM15707','EM15708','EM15709','EM15710']
# Create a new figure for the violin plot
plt.figure(figsize=(10,6))

# set font size of axis labels
sns.set(style="white", font_scale=1.5)
# Create the figure and axes
fig, ax = plt.subplots(figsize=(6, 5))

# Create the boxenplot plot
sns.violinplot(x="IMAGE", y="SHAPE.curvature", inner='quartile',
              color="darkgray", scale='width', linewidth=2, cut=False, width=0.8,
              data=df, order=order)
# Set plot labels and title
plt.xlabel('Strain')
plt.ylabel('Curvature', size=24)
plt.title('Curvature')
plt.ylim([0, .8])  # adjust as needed
   
# Define and set y-ticks using the axes object
y_ticks = np.arange(0, 0.6 + 0.2, 0.2)  # Adjust the range as needed
y_tick_labels = [f"{y:.1f}" for y in y_ticks]  # Format to one decimal place
ax.set_yticks(y_ticks)
ax.set_yticklabels(y_tick_labels, fontsize=16)

# Add minor ticks on y-axis without labels
ax.yaxis.set_minor_locator(mticker.MultipleLocator(.1))

# Manually add major y-tick lines
tick_length_major = 0.0225  # Adjust as needed
major_tick_width = 2  # Adjust for desired major tick line width
for y_tick in y_ticks:
    ax.plot([-tick_length_major, 0], [y_tick, y_tick], color='black', clip_on=False, transform=ax.get_yaxis_transform())

# Manually add minor y-tick lines
tick_length_minor = 0.0175  # Adjust as needed, typically smaller than major ticks
minor_y_ticks = np.arange(0, 0.65, 0.1)  # Assuming your y-axis ranges from 0 to 0.65
minor_tick_width = 2000  # Adjust for desired major tick line width
for y_tick_minor in minor_y_ticks:
    if y_tick_minor not in y_ticks:  # This check ensures that we don't overlap with major ticks
        ax.plot([-tick_length_minor, 0], [y_tick_minor, y_tick_minor], color='black', clip_on=False, transform=ax.get_yaxis_transform())

# Manually add x-tick lines
x_ticks = ax.get_xticks()  # Get the x-tick positions (assuming they are already set)
for x_tick in x_ticks:
    ax.plot([x_tick, x_tick], [-tick_length, 0], color='black', clip_on=False, transform=ax.get_xaxis_transform())


# Adjust tick lengths and widths for both minor and major ticks
ax.tick_params(axis='y', which='minor', length=5)
ax.tick_params(axis='y', which='major', length=10)
ax.tick_params(axis='x', which='major', length=8)    
        
plt.title('')
plt.xlabel('', fontsize=12)
plt.ylabel('Cell curvature', fontsize=26)
# set font size of tick labels
plt.xticks(fontsize=12)
plt.yticks(y_ticks,fontsize=18)

# Set the y-axis range
plt.ylim(0, 0.65)

# Increase the width of the axes and frame
for spine in plt.gca().spines.values():
    spine.set_linewidth(2)  # Adjust the width as needed

plt.legend().remove()

plt.savefig('Curvature_ViolinPlot_Mod.tiff', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
